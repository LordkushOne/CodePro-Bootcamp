# %%
print("hola mundo")
# Out:
# hola mundo

# %%
# variables

mi_nombre= 'Franco' 
mi_edad= 27
mi_ciudad= 'asuncion' 

# texto impreso
print('Mi nombre es', mi_nombre , 'mi edad es', mi_edad , 'mi ciudad actual es', mi_ciudad)
# Out:
# Mi nombre es Franco mi edad es 27 mi ciudad actual es asuncion

# %%
# suma de frutas

cantidad_de_manzanas= 3
cantidad_de_naranjas= 5

# resultado de frutas
print(cantidad_de_manzanas + cantidad_de_naranjas)

# resta de frutas

cantidad_de_manzanas_vendidas= 2
cantidad_de_naranjas_vendidas= 4

# frutas restantes
print(cantidad_de_naranjas_vendidas - cantidad_de_manzanas_vendidas
      )
# Out:
# 8
# 2

# %%
# Asignar el nombre y apellido de mi compañero

nombre= 'Guillermo'
apellido= 'Lopez'

# Hacer un saludo
saludo= (f'Hola me llamo {nombre} y mi apellido es {apellido} mucho gusto')

# Imprimir la variable saludo
print(f'Hola mi nombre es {nombre} y mi apellido es {apellido} un saludo')
# Out:
# Hola mi nombre es Guillermo y mi apellido es Lopez un saludo

# %%
# Sumar la cantidad de pedidos

# Sumar las cantidades de pedidos del numero1 y numero2
numero1 = int(input('numero1'))
numero2 = int(input('numero2'))

# Sumar los pedidos de numero1 y numero2
print(numero1+numero2)

# %%
# Aca empieza la funcion de preparacion

def preparacion():
    print('En proceso de calentamiento')
    print('Aguarde un instante')
    print('Su pedido a sido completado')
# Aqui termina la funcion

preparacion()
preparacion()
preparacion()
preparacion()

# %%
# Funcion que pregunta caracteristicas de un elemento para comprar

def mostrar_producto(articulo_especifico1 , articulo_especifico2 , articulo_especifico3):
     print("Hola, que articulo necesita")
     print(f"Necesito una {x} para hacer una {y} y poder ponerla en {z}")
     print("")
     precio = input("precio del produNombrecto")
    color = input("color del producto")
    marca = input("marca del producto")

    print(f"Nombre del producto {Nombre}, precio del producto {precio}, color del producto {color}, marca del productor {marca}")

# %%
# Funcion que hace pregunta por las caracteristicas de un producto

def producto_a_comprar(x , y , z):
    print("Buenas tardes queria hacer una consulta por el siguiente producto")
    print(f"El productor que necesito es {x} , para que {y} , se pueda utilizar con {z}")

especificacion1 = input("Defina el producto")
especificacion2 = input("Caracteristicas del producto")
especificacion3 = input("Diganos para que lo necesita")

articulo_a_comprar("especificacion1 especificacion2 especificacion3")

articulo_a_comprar("Casco" , "1/2" , "150cc")
articulo_a_comprar("Cubierta" , "trasera" , "R15")
articulo_a_comprar("Rayos" , "espejo" , "foco")
