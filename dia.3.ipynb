# %%
#Crear una funcion que reciba dos letras (parametros) y verifique si son iguales:
#1. Si son iguales, imprimir "Las letras son iguales"
#2. De lo contrario, imprimir "Las letras son diferentes"

letra1 = "a"
letra2 = "b"

def verificar_letra(letra1, letra2):
    if letra1 == letra2:
       print("Las letra no son iguales")
    else:
        print("Las letras son distintas")

verificar_letra()

# %%
#Crear una funcion que reciba dos parametros (una palabra y un numero), y que retorne True y si el numero 
#es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.

def contar(palabra, numero):
    if len (palabra) == numero:
        return True
    else:
        return False
contar(palabra, numero)

# %%
#Crear funcion que revise si una palabra contiene una letra. En caso de que la contenga, retornar la letra entre []
#De lo contrario, retornar solo la letra.

funcion = input("Corrobora si una palabra contiene una letra")
condicion = "a"


def revisar_letra_en_palabra(letra, palabra):
    if funcion in condicion:
     return f"[{condicion}]"
    else:
       return condicion
revisar_letra_en_palabra(funcion, condicion)
# Out:
# 'a'

# %%
#Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list()
#Agregar esa lista de caracteres a una lista llamada palabras_ingresadas
#Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas

#definir una variable palabra=input()
#convertir palabra a lista con lista_de_palabra = list(palabra)

#creamos otra lista llamada: palabras_ingresadas
#palabras_ingresadas.apped(lista_de_palabra)

#Probar un bucle que repita 3 veces el proceso siguiente:

palabras_ingresadas = []

for i in range(3):

    palabra = input("Ingresar palabra")

    lista_usuario = list(palabra)

    palabras_ingresadas.append(lista_usuario)

    print(palabras_ingresadas)

# %%
#Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.

lista = [['h', 'o', 'l', 'i', 's']['h', 'e', 'l', 'l', 'o']['h', 'a', 'l', 'l', 'o']]

for i in lista:
    print(i)
